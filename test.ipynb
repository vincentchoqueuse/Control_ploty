# %% [markdown]
# # Test Jupyter

# %%
from control import *
from ENIB_control import *

sys1 = tf([3],[1,3])
sys2 = tf([2],[1,2,5])

# %% [markdown]
# ## Impulse Reponse

# %%
impulse([sys1,sys2])
# Out:
# <div>
#
#
#             <div id="cc21f2f7-1c44-4980-9420-04f7e2f362b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cc21f2f7-1c44-4980-9420-04f7e2f362b5")) {
#                     Plotly.newPlot(
#                         'cc21f2f7-1c44-4980-9420-04f7e2f362b5',
# ...

# %% [markdown]
# ## Step Response

# %%
step([sys1,sys2])
# Out:
# <div>
#
#
#             <div id="96c9a8ec-36ed-4187-9893-e18c2affa883" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("96c9a8ec-36ed-4187-9893-e18c2affa883")) {
#                     Plotly.newPlot(
#                         '96c9a8ec-36ed-4187-9893-e18c2affa883',
# ...

# %% [markdown]
# ## Bode

# %%
bode([sys1,sys2])
# Out:
# <div>
#
#
#             <div id="564d03e8-cca9-4561-9372-0ae12590dcef" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("564d03e8-cca9-4561-9372-0ae12590dcef")) {
#                     Plotly.newPlot(
#                         '564d03e8-cca9-4561-9372-0ae12590dcef',
# ...

# %% [markdown]
# ## Black Nichols

# %%
cl_mags = np.array([6,0,-1,-2,-5,-10,-20])
nichols([sys1,sys2],cl_mags = cl_mags)
# Out:
# <div>
#
#
#             <div id="cd9851f0-6e8e-4f13-bf6b-df641049699c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cd9851f0-6e8e-4f13-bf6b-df641049699c")) {
#                     Plotly.newPlot(
#                         'cd9851f0-6e8e-4f13-bf6b-df641049699c',
# ...
